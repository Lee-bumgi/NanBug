# %% [markdown]
# # 주제 : 자작곡 공개합니다!! 줄없는 기타! 에어 기타!(꿀잼) [겜도리]

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
#1. 브라우저를 실행 > 유튜브채널 사이트로!
driver = wb.Chrome(f'C:/chrome/chromedriver.exe')   
b="https://www.youtube.com/watch?v=0vId14APdxE"
driver.get(b)
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_16868\1758954540.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wb.Chrome(f'C:/chrome/chromedriver.exe')

# %%
#2. 댓글정보를 수집
review = driver.find_elements(By.ID,"content-text")
all = ""
for i in review :
    print(i.text)
    all += i.text
# Out:
# 노래가 맘에 드신다면?! 구독&좋아요
# 뭔 가수보는보는것같아요!
# 노래 진짜 잘부르셔요!ㅎㅎ
# 작곡자도 울고갈만한 작곡실력 부러워요ㅠㅠ
# 오~ 신기한 장난감이네요!!
# 줄 없이도 연주가 된다니....
# 그 보다 더 신기한 것은 숨겨왔던 겜도리님의 노래실력!!!
# 노래 정~~말~~ 잘 부르세요!!!
# 뭣보다 겜도리님 노래 진짜진짜진짜 잘불르시네요ㅠㅠ 얼굴도 잘생겼지 노래도 잘부르시지 성격도 착하시지 맘찢남..
# 노래는 징짜 맘에 든다!! 근데 구독자가 왜 안오르지 노래컨텐츠 가끔해주세요 겜도리님!
# 와 진짜 의외로 잘 됰ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# 와 노래 부르는거 보고 ㄹㅇ개깜짝 놀람 ㄷㄷ;;;노래 씹개잘부른다 와 노래 커버 한번 해주면 조횟수 폭발각
# 겜돌이님 노래 진짜 잘 부르시네요
# 와~~~~레알 명곡 ㅜㅜ
# 노래 진짜 잘하시네요~~
# 낚신줄알았는데 진짜 잘부르네ㄲㅋㅋㅋㄷㄷ
# 정말 목소리도 좋고 노래도 좋내요
# 의외로 노래잘하시네♡♡
# 노래 진짜  와 말로표현살수가 없어요
# 노래가 좋당!!
# 잘부루고있어서놀랐는데군인할때터짐ㅋㅋㅋㅋ
# ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ겜돌님완전실력자네요ㅠㅠ
# 고음내는거 봐라 ㅎㄷㄷㄷ
# 노래에 소질있는 그는 겜도리..
# 옼ㅋㅋㅋㅋ정말 좋네요ㅋㅋ
# 명곡이다!! ㅋㅋ
# 이분들 단체로 보컬같은거 전공하셨나..
# 노래 잘하시네요 ^^  좋아요 누르고 갑니당 ^^
# 노래 잘 지으세요~좋아요 누르고 갑니다
# 와..ㅋㅋ노래 짱잘!!
# 노래가 너무 좋아요
# 박자가 단순한데 노래랑 잘맞아서 괜찮다
# 겜도리님 노래 잘부르시네요!
# 우와~~~~ 노래실력 대박!!!!!!!!!!
# 근데 가사 군인에서 빵~~ㅋㅋㅋㅋ
# 꾹티비님은 노래할때 육개장을 귀에꽃으시고,겜돌님은 컵을..브라운걸님은 뭘꽃으실지궁금하닼ㅋㅋ
# 노래 잘하시네요.가수하셔도 되겠어요.
# 와 노래 잘부르신다
# 노래 잘 부르세요!!!
# 이야~음원판매해도될듯
# 잘 봤어요. ^^
# 고음 잘하신다!!!!🖒
# ...

# %% [markdown]
# # 단어가 있는것들중에 상위 15개 단어 시각화 하기

# %%
from konlpy.tag import Okt
okt = Okt() #코넬피 호출
okt.nouns  #코넬피.명사
nounsword = okt.nouns(all) #전체 댓글중에 명사들만 호출하기 
temp = nounsword.copy() #명사들만 호출한거 temp에 넣기
for i in temp:         # temp 안에 한개씩 호출
    if len(i) == 1:    # 길이가 한개인 단어일경우
        nounsword.remove(i) #제거함
from collections import Counter
count = dict(Counter(nounsword).most_common(15)) #명사 갯수는 몇개?
import matplotlib.pyplot as plt #매트플로리프 호출
from matplotlib import font_manager, rc #한글 되는거 호출
plt.rcParams['axes.unicode_minus'] = False

font_path = "c:/Windows/Fonts/malgun.ttf" #한글 폰트 부르기

font_name = font_manager.FontProperties(fname=font_path).get_name() #한글 폰트 불러서 적용준비하기
rc('font', family=font_name) #적용하기

count = dict(Counter(nounsword).most_common(15)) #상위 15개 뽑기
print(count)
plt.figure(figsize=(15,15))
plt.bar(count.keys(), count.values())
plt.savefig("./보고서3plt.jpg")
# Out:
# {'노래': 56, '겜도리': 21, '군인': 14, '진짜': 8, '학생': 7, '대박': 6, '꿀잼': 6, '가수': 5, '오늘': 5, '구독': 4, '정말': 4, '겜돌': 4, '기타': 4, '언제': 4, '사람': 4}

# %%
from wordcloud import WordCloud # 클래스
wc = WordCloud(background_color="white", 
               font_path="C:\Windows\Fonts\malgunsl.ttf",
               random_state=802)
reviews = " ".join(nounsword) # 하나의 문자열로 변경
cloud = wc.generate_from_text(reviews)
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
plt.imshow(cloud)
plt.axis("off") # x축,y축 끄기
plt.savefig("./보고서3.jpg") # 그림저장
plt.show()

# %%
for i in range(120) :
    body = driver.find_element(By.TAG_NAME,"body")
    body.send_keys(Keys.END)
    time.sleep(0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
#       2 body = driver.find_element(By.TAG_NAME,"body")
#       3 body.send_keys(Keys.END)
# ----> 4 time.sleep(0.5)
#
# KeyboardInterrupt:
