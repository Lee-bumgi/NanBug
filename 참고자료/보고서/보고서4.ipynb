# %% [markdown]
# # 주제 : An actual Air Guitar that you can buy

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
#1. 브라우저를 실행 > 유튜브채널 사이트로!
driver = wb.Chrome(f'C:/chrome/chromedriver.exe')   
b="https://www.youtube.com/watch?v=WEQoGod1wPA"
driver.get(b)
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_23280\3751456795.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wb.Chrome(f'C:/chrome/chromedriver.exe')

# %%
#2. 댓글정보를 수집
review = driver.find_elements(By.ID,"content-text")
all = ""
for i in review :
    print(i.text)
    all += i.text
# Out:
# For about 6 years, did not know how to use it and just used it as a cat toy. Now I know how to use it! (Still only use it as a cat toy)
# I bought one at a used store in Dartmouth Nova Scotia for 3 bucks Canadian. An original. OMG I am blown away at what this little thing can do and don't get me started on the I/O ports. Synthesisers man synths. Holy crap this is a bullet with a bite that is sure to have a coveted spot in my electronic setup.
# I absolutely hate too but I kinda want one! For free.
# You hate it but I want one. It’s sooo cheap and bad but will be fun to circuit bend and then mash into a bunch of effects. About 10usd on eBay
# Perfect for circuit bending!!
# I absolutely hate too but I kinda want one! For free.
#
#
# An actual Air Guitar that you can buy
# looks like cheap bad toy

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))


word_tokens = word_tokenize(str(all))  
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        new_string = ''.join(char for char in w if char.isalnum())
        if new_string != '' and new_string != 'I' and 1 != len(new_string) :
            filtered_sentence.append(new_string)
        
print(filtered_sentence)
# Out:
# ['For', 'years', 'know', 'use', 'used', 'cat', 'toy', 'Now', 'know', 'use', 'Still', 'use', 'cat', 'toy', 'bought', 'one', 'used', 'store', 'Dartmouth', 'Nova', 'Scotia', 'bucks', 'Canadian', 'An', 'original', 'OMG', 'blown', 'away', 'little', 'thing', 'nt', 'get', 'started', 'IO', 'ports', 'Synthesisers', 'man', 'synths', 'Holy', 'crap', 'bullet', 'bite', 'sure', 'coveted', 'spot', 'electronic', 'setupI', 'absolutely', 'hate', 'kinda', 'want', 'one', 'For', 'freeYou', 'hate', 'want', 'one', 'It', 'sooo', 'cheap', 'bad', 'fun', 'circuit', 'bend', 'mash', 'bunch', 'effects', 'About', '10usd', 'eBayPerfect', 'circuit', 'bending', 'absolutely', 'hate', 'kinda', 'want', 'one', 'For', 'free', 'An', 'actual', 'Air', 'Guitar', 'buylooks', 'like', 'cheap', 'bad', 'toy']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from wordcloud import WordCloud # 클래스
wc = WordCloud(background_color="white", 
               font_path="C:\Windows\Fonts\malgunsl.ttf",
               random_state=802)
reviews = " ".join(filtered_sentence) # 하나의 문자열로 변경
cloud = wc.generate_from_text(reviews)
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
plt.imshow(cloud)
plt.axis("off") # x축,y축 끄기
plt.savefig("./보고서4.jpg") # 그림저장
plt.show()

# %% [markdown]
# # 단어가 있는것들중에 상위 15개 단어 시각화 하기

# %%
from collections import Counter
wordcount = Counter(filtered_sentence)
print(wordcount.most_common())
temp = wordcount.copy() #명사들만 호출한거 temp에 넣기
for i in temp:         # temp 안에 한개씩 호출
    if len(i) == 1:    # 길이가 한개인 단어일경우
        del wordcount[i]#제거함
import collections
import matplotlib.pyplot as plt
count = dict(Counter(wordcount).most_common(15)) #상위 15개 뽑기
print(count)
plt.figure(figsize=(15,15), dpi=80)
plt.bar(count.keys(), count.values())
plt.savefig("./보고서4plt.jpg") # 그림저장

plt.show()
# Out:
# [('one', 4), ('For', 3), ('use', 3), ('toy', 3), ('hate', 3), ('want', 3), ('know', 2), ('used', 2), ('cat', 2), ('An', 2), ('absolutely', 2), ('kinda', 2), ('cheap', 2), ('bad', 2), ('circuit', 2), ('years', 1), ('Now', 1), ('Still', 1), ('bought', 1), ('store', 1), ('Dartmouth', 1), ('Nova', 1), ('Scotia', 1), ('bucks', 1), ('Canadian', 1), ('original', 1), ('OMG', 1), ('blown', 1), ('away', 1), ('little', 1), ('thing', 1), ('nt', 1), ('get', 1), ('started', 1), ('IO', 1), ('ports', 1), ('Synthesisers', 1), ('man', 1), ('synths', 1), ('Holy', 1), ('crap', 1), ('bullet', 1), ('bite', 1), ('sure', 1), ('coveted', 1), ('spot', 1), ('electronic', 1), ('setupI', 1), ('freeYou', 1), ('It', 1), ('sooo', 1), ('fun', 1), ('bend', 1), ('mash', 1), ('bunch', 1), ('effects', 1), ('About', 1), ('10usd', 1), ('eBayPerfect', 1), ('bending', 1), ('free', 1), ('actual', 1), ('Air', 1), ('Guitar', 1), ('buylooks', 1), ('like', 1)]
# {'one': 4, 'For': 3, 'use': 3, 'toy': 3, 'hate': 3, 'want': 3, 'know': 2, 'used': 2, 'cat': 2, 'An': 2, 'absolutely': 2, 'kinda': 2, 'cheap': 2, 'bad': 2, 'circuit': 2}
