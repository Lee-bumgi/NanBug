# %% [markdown]
# # 주제 : My Worst Purchase - Infrared Air Guitar by Jie-Star - Review And Demonstration

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
#1. 브라우저를 실행 > 유튜브채널 사이트로!
driver = wb.Chrome(f'C:/chrome/chromedriver.exe')   
b="https://www.youtube.com/watch?v=-0LJ0jPRHE0"
driver.get(b)
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_20944\1887640811.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wb.Chrome(f'C:/chrome/chromedriver.exe')

# %%
#2. 댓글정보를 수집
review = driver.find_elements(By.ID,"content-text")
all = ""
for i in review :
    print(i.text)
    all += i.text
# Out:
# There is a video out there that the person does Back in Black from ACDC on this. Sure it didnt sound the best, but that being said. It is a toy. I figure if it keeps a kid busy for a few hours, it's worth it. Depending on the kid of course. They might need to play outside with it. Otherwise it may drive you batty.
# this is hilarious. top tier satirical review. 10/10
# A fun review of a broken toy. Funny and cool! Thank!
# If even Mykola's wonderful sense of humour cannot save that product, nothing can!
# That jimi hendrix part is hilarious!
# I don't know if it would make a good sniper laser with how loud it is XD
# But in all seriousness nice video, keep up the good work!
# I love your channel. Great job!
# I want one as a second guitar. Right now
# That is a cheap Chinese clone of the air guitar pro buy tomy. The actual one is much better, and I suggest you try it out if you can find one for sale online.
# Great review. Very interesting.
# Damn, it was a great review! )
# Haha!  Never know what you will upload next  Great job!
# На этой штуке нужно сыграть Летова
# Wow, what a pointless product
# i blame your placment of where the laser is shining. It probably thought your arm was your hand and when your hand did come back, the laser didnt think it ever left.
# Wow am so happy to see youu back
# Полнейшая дичь эта гитара)))
# The guy who sing " waw you can really dance " song
# Русский акцент
# Nice!
# Look schibo toy guitar if you want to see people actually playing quite well with it. Maybe it is you?
# lol there is no Cb chord or note.
# Accent: Sinking
# C bemol
# четко
# DEE PURPOLE
# Let us repent from our sins and accept Jesus as our Lord and Savior one day we will face him and those who doesn't repent from there sins and didn't accept Jesus as our Lord and Savior would be sent to hell for he didn't want God so he will go to place where God is nowhere to be found but the good news is this Jesus has already died for you so you don't have to suffer hell  all you need to do is accept Jesus as your Lord and Savior and repent from your sins you will be saved that Is the good news my friends that salvation is free thats all ask me if your confused at something God bless you
# Раша из зэ кэпитал оф грейт британ
# arowsmeet

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))


word_tokens = word_tokenize(str(all))  
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        new_string = ''.join(char for char in w if char.isalnum())
        if new_string != '' and new_string != 'I' and 1 != len(new_string) :
            filtered_sentence.append(new_string)
        
print(filtered_sentence)
# Out:
# ['There', 'video', 'person', 'Back', 'Black', 'ACDC', 'Sure', 'didnt', 'sound', 'best', 'said', 'It', 'toy', 'figure', 'keeps', 'kid', 'busy', 'hours', 'worth', 'Depending', 'kid', 'course', 'They', 'might', 'need', 'play', 'outside', 'Otherwise', 'may', 'drive', 'battythis', 'hilarious', 'top', 'tier', 'satirical', 'review', '1010A', 'fun', 'review', 'broken', 'toy', 'Funny', 'cool', 'Thank', 'If', 'even', 'Mykola', 'wonderful', 'sense', 'humour', 'save', 'product', 'nothing', 'That', 'jimi', 'hendrix', 'part', 'hilarious', 'nt', 'know', 'would', 'make', 'good', 'sniper', 'laser', 'loud', 'XD', 'But', 'seriousness', 'nice', 'video', 'keep', 'good', 'work', 'love', 'channel', 'Great', 'job', 'want', 'one', 'second', 'guitar', 'Right', 'nowThat', 'cheap', 'Chinese', 'clone', 'air', 'guitar', 'pro', 'buy', 'tomy', 'The', 'actual', 'one', 'much', 'better', 'suggest', 'try', 'find', 'one', 'sale', 'onlineGreat', 'review', 'Very', 'interestingDamn', 'great', 'review', 'Haha', 'Never', 'know', 'upload', 'next', 'Great', 'job', 'На', 'этой', 'штуке', 'нужно', 'сыграть', 'ЛетоваWow', 'pointless', 'product', 'blame', 'placment', 'laser', 'shining', 'It', 'probably', 'thought', 'arm', 'hand', 'hand', 'come', 'back', 'laser', 'didnt', 'think', 'ever', 'leftWow', 'happy', 'see', 'youu', 'backПолнейшая', 'дичь', 'эта', 'гитара', 'The', 'guy', 'sing', 'waw', 'really', 'dance', 'songРусский', 'акцентNice', 'Look', 'schibo', 'toy', 'guitar', 'want', 'see', 'people', 'actually', 'playing', 'quite', 'well', 'Maybe', 'lol', 'Cb', 'chord', 'noteAccent', 'SinkingC', 'bemol', 'четкоDEE', 'PURPOLELet', 'us', 'repent', 'sins', 'accept', 'Jesus', 'Lord', 'Savior', 'one', 'day', 'face', 'nt', 'repent', 'sins', 'nt', 'accept', 'Jesus', 'Lord', 'Savior', 'would', 'sent', 'hell', 'nt', 'want', 'God', 'go', 'place', 'God', 'nowhere', 'found', 'good', 'news', 'Jesus', 'already', 'died', 'nt', 'suffer', 'hell', 'need', 'accept', 'Jesus', 'Lord', 'Savior', 'repent', 'sins', 'saved', 'Is', 'good', 'news', 'friends', 'salvation', 'free', 'thats', 'ask', 'confused', 'something', 'God', 'bless', 'youРаша', 'из', 'зэ', 'кэпитал', 'оф', 'грейт', 'британarowsmeet']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from wordcloud import WordCloud # 클래스
wc = WordCloud(background_color="white", 
               font_path="C:\Windows\Fonts\malgunsl.ttf",
               random_state=802)
reviews = " ".join(filtered_sentence) # 하나의 문자열로 변경
cloud = wc.generate_from_text(reviews)
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
plt.imshow(cloud)
plt.axis("off") # x축,y축 끄기
plt.savefig("./보고서5.jpg") # 그림저장
plt.show()

# %% [markdown]
# # 단어가 있는것들중에 상위 15개 단어 시각화 하기

# %%
from collections import Counter
wordcount = Counter(filtered_sentence)
print(wordcount.most_common())
temp = wordcount.copy() #명사들만 호출한거 temp에 넣기
for i in temp:         # temp 안에 한개씩 호출
    if len(i) == 1:    # 길이가 한개인 단어일경우
        del wordcount[i]#제거함
import collections
import matplotlib.pyplot as plt
count = dict(Counter(wordcount).most_common(15)) #상위 15개 뽑기
print(count)
plt.figure(figsize=(15,15), dpi=80)
plt.bar(count.keys(), count.values())
plt.savefig("./보고서5plt.jpg") # 그림저장
plt.show()
# Out:
