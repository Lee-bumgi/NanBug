# %% [markdown]
# # 주제 : Guitar Songs - Infrared Sensor Air Guitar with 10 Built-In Songs MZC142248

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
#1. 브라우저를 실행 > 유튜브채널 사이트로!
driver = wb.Chrome(f'C:/chrome/chromedriver.exe')   
b="https://www.youtube.com/watch?v=KVApAAWORj8"
driver.get(b)
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_20560\2343236431.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wb.Chrome(f'C:/chrome/chromedriver.exe')

# %%
#2. 댓글정보를 수집
review = driver.find_elements(By.ID,"content-text")
all = ""
for i in review :
    print(i.text)
    all += i.text
# Out:
# How did life get you this far.
# This is the “how to basic” version of demo videos. The shirt seals the deal.
# Even the air guitar pro that this is a clone of works better than that.
# God Christ Jesus bless you, have a nice day today my family
# wow. does not work at all. how is this playing a guitar! !!
# tchibo air guitar is better
# ?
# Sorry dude, try another thing, maybe futbol
# boooooo

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))


word_tokens = word_tokenize(str(all))  
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        new_string = ''.join(char for char in w if char.isalnum())
        if new_string != '' and new_string != 'I' and 1 != len(new_string) :
            filtered_sentence.append(new_string)
        
print(filtered_sentence)
# Out:
# ['How', 'life', 'get', 'farThis', 'basic', 'version', 'demo', 'videos', 'The', 'shirt', 'seals', 'dealEven', 'air', 'guitar', 'pro', 'clone', 'works', 'better', 'thatGod', 'Christ', 'Jesus', 'bless', 'nice', 'day', 'today', 'familywow', 'work', 'playing', 'guitar', 'tchibo', 'air', 'guitar', 'better', 'Sorry', 'dude', 'try', 'another', 'thing', 'maybe', 'futbolboooooo']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from wordcloud import WordCloud # 클래스
wc = WordCloud(background_color="white", 
               font_path="C:\Windows\Fonts\malgunsl.ttf",
               random_state=802)
reviews = " ".join(filtered_sentence) # 하나의 문자열로 변경
cloud = wc.generate_from_text(reviews)
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
plt.imshow(cloud)
plt.axis("off") # x축,y축 끄기
plt.savefig("./보고서6.jpg") # 그림저장
plt.show()

# %% [markdown]
# # 단어가 있는것들중에 상위 15개 단어 시각화 하기

# %%
from collections import Counter
wordcount = Counter(all.split())
print(wordcount.most_common())
temp = wordcount.copy() #명사들만 호출한거 temp에 넣기
for i in temp:         # temp 안에 한개씩 호출
    if len(i) == 1:    # 길이가 한개인 단어일경우
        del wordcount[i]#제거함
import collections
import matplotlib.pyplot as plt
count = dict(Counter(filtered_sentence).most_common(15)) #상위 15개 뽑기
print(count)
plt.figure(figsize=(15,15), dpi=80)
plt.bar(count.keys(), count.values())
plt.savefig("./보고서6plt.jpg")
plt.show()
# Out:
# [('is', 4), ('this', 3), ('the', 3), ('a', 3), ('of', 2), ('air', 2), ('guitar', 2), ('How', 1), ('did', 1), ('life', 1), ('get', 1), ('you', 1), ('far.This', 1), ('“how', 1), ('to', 1), ('basic”', 1), ('version', 1), ('demo', 1), ('videos.', 1), ('The', 1), ('shirt', 1), ('seals', 1), ('deal.Even', 1), ('pro', 1), ('that', 1), ('clone', 1), ('works', 1), ('better', 1), ('than', 1), ('that.God', 1), ('Christ', 1), ('Jesus', 1), ('bless', 1), ('you,', 1), ('have', 1), ('nice', 1), ('day', 1), ('today', 1), ('my', 1), ('familywow.', 1), ('does', 1), ('not', 1), ('work', 1), ('at', 1), ('all.', 1), ('how', 1), ('playing', 1), ('guitar!', 1), ('!!tchibo', 1), ('better?Sorry', 1), ('dude,', 1), ('try', 1), ('another', 1), ('thing,', 1), ('maybe', 1), ('futbolboooooo', 1)]
# {'guitar': 3, 'air': 2, 'better': 2, 'How': 1, 'life': 1, 'get': 1, 'farThis': 1, 'basic': 1, 'version': 1, 'demo': 1, 'videos': 1, 'The': 1, 'shirt': 1, 'seals': 1, 'dealEven': 1}
