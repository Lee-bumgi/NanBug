# %% [markdown]
# # Air Guitar Pro, Toy Guitar by Takara Tomy (2007, Japan)

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
#1. 브라우저를 실행 > 유튜브채널 사이트로!
driver = wb.Chrome(f'C:/chrome/chromedriver.exe')   
b="https://www.youtube.com/watch?v=eDtF8FZGSBo"
driver.get(b)
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_672\3486698250.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wb.Chrome(f'C:/chrome/chromedriver.exe')

# %%
#2. 댓글정보를 수집
review = driver.find_elements(By.ID,"content-text")
all = ""
for i in review :
    print(i.text)
    all += i.text
# Out:
# This video is soo well made! Amazing!!
# Hey, thank you for visiting!
# Comatox voy hb
# Wanna try using this next to a fan for fast strumming
# Did I just heard let it be in the end?
# Can you palm mute?
# I tihink it harder to play than original guitar.
# some chords are pretty hard to execute unless you have super long fingers, that said, I still think real guitars are rightfully harder to learn and play well.
# Does it djent?
# LOL
# lmao
# its beautiful lol
#
# God Christ Jesus bless you all my family, have a nice day today
# Let It Be!
# Harganya brapa?belinya dmana?
# hi, you can check out this page on Amazon.
# https://www.amazon.com/s/ref=nb_sb_noss?url=search-alias%3Dtoys-and-games&field-keywords=Air+Guitar+Pro
# KNTL!!!
# Jeff Gaming Chanel kalem kalem

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))


word_tokens = word_tokenize(str(all))  
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        new_string = ''.join(char for char in w if char.isalnum())
        if new_string != '' and new_string != 'I' and 1 != len(new_string) :
            filtered_sentence.append(new_string)
        
print(filtered_sentence)
# Out:
# ['This', 'video', 'soo', 'well', 'made', 'Amazing', 'Hey', 'thank', 'visiting', 'Comatox', 'voy', 'hbWanna', 'try', 'using', 'next', 'fan', 'fast', 'strummingDid', 'heard', 'let', 'end', 'Can', 'palm', 'mute', 'tihink', 'harder', 'play', 'original', 'guitarsome', 'chords', 'pretty', 'hard', 'execute', 'unless', 'super', 'long', 'fingers', 'said', 'still', 'think', 'real', 'guitars', 'rightfully', 'harder', 'learn', 'play', 'well', 'Does', 'djent', 'LOLlmaoits', 'beautiful', 'lol', 'God', 'Christ', 'Jesus', 'bless', 'family', 'nice', 'day', 'todayLet', 'It', 'Be', 'Harganya', 'brapa', 'belinya', 'dmana', 'hi', 'check', 'page', 'Amazon', 'https', 'wwwamazoncomsrefnbsbnoss', 'urlsearchalias', '3Dtoysandgames', 'fieldkeywordsAirGuitarProKNTL', 'Jeff', 'Gaming', 'Chanel', 'kalem', 'kalem']
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from wordcloud import WordCloud # 클래스
wc = WordCloud(background_color="white", 
               font_path="C:\Windows\Fonts\malgunsl.ttf",
               random_state=802)
reviews = " ".join(filtered_sentence) # 하나의 문자열로 변경
cloud = wc.generate_from_text(reviews)
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
plt.imshow(cloud)
plt.axis("off") # x축,y축 끄기
plt.savefig("./보고서2.jpg") # 그림저장
plt.show()

# %%
from collections import Counter
wordcount = Counter(filtered_sentence)
print(wordcount.most_common())
temp = wordcount.copy() #명사들만 호출한거 temp에 넣기
for i in temp:         # temp 안에 한개씩 호출
    if len(i) == 1:    # 길이가 한개인 단어일경우
        del wordcount[i]#제거함
import collections
import matplotlib.pyplot as plt
count = dict(Counter(wordcount).most_common(15)) #상위 15개 뽑기
print(count)
plt.figure(figsize=(15,15), dpi=80)
plt.bar(count.keys(), count.values())
plt.savefig("./보고서2plt.jpg") # 그림저장
plt.show()
# Out:
# [('well', 2), ('harder', 2), ('play', 2), ('kalem', 2), ('This', 1), ('video', 1), ('soo', 1), ('made', 1), ('Amazing', 1), ('Hey', 1), ('thank', 1), ('visiting', 1), ('Comatox', 1), ('voy', 1), ('hbWanna', 1), ('try', 1), ('using', 1), ('next', 1), ('fan', 1), ('fast', 1), ('strummingDid', 1), ('heard', 1), ('let', 1), ('end', 1), ('Can', 1), ('palm', 1), ('mute', 1), ('tihink', 1), ('original', 1), ('guitarsome', 1), ('chords', 1), ('pretty', 1), ('hard', 1), ('execute', 1), ('unless', 1), ('super', 1), ('long', 1), ('fingers', 1), ('said', 1), ('still', 1), ('think', 1), ('real', 1), ('guitars', 1), ('rightfully', 1), ('learn', 1), ('Does', 1), ('djent', 1), ('LOLlmaoits', 1), ('beautiful', 1), ('lol', 1), ('God', 1), ('Christ', 1), ('Jesus', 1), ('bless', 1), ('family', 1), ('nice', 1), ('day', 1), ('todayLet', 1), ('It', 1), ('Be', 1), ('Harganya', 1), ('brapa', 1), ('belinya', 1), ('dmana', 1), ('hi', 1), ('check', 1), ('page', 1), ('Amazon', 1), ('https', 1), ('wwwamazoncomsrefnbsbnoss', 1), ('urlsearchalias', 1), ('3Dtoysandgames', 1), ('fieldkeywordsAirGuitarProKNTL', 1), ('Jeff', 1), ('Gaming', 1), ('Chanel', 1)]
# {'well': 2, 'harder': 2, 'play': 2, 'kalem': 2, 'This': 1, 'video': 1, 'soo': 1, 'made': 1, 'Amazing': 1, 'Hey': 1, 'thank': 1, 'visiting': 1, 'Comatox': 1, 'voy': 1, 'hbWanna': 1}
