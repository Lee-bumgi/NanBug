# %% [markdown]
# # 주제 : AIR GUITAR PRO "ACOUSTIC GUITAR" タカラトミー エアギタープロ

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
#1. 브라우저를 실행 > 유튜브채널 사이트로!
driver = wb.Chrome(f'C:/chrome/chromedriver.exe')   
b="https://www.youtube.com/watch?v=0Zz9c6dpMS0"
driver.get(b)
# Out:
# C:\Users\AI\AppData\Local\Temp\ipykernel_9820\4224838798.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wb.Chrome(f'C:/chrome/chromedriver.exe')
# C:\Users\AI\AppData\Local\Temp\ipykernel_9820\4224838798.py:6: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = wb.Chrome(f'C:/chrome/chromedriver.exe')

# %%
#2. 댓글정보를 수집
review = driver.find_elements(By.ID,"content-text")
all = ""
for i in review :
    print(i.text)
    all += i.text
# Out:
# You are the best !
# never seen before a guitar player with great talent as you.
# Congratulation and see you on MTV.
# He was pretty fast at the 1:20 mark, looks like he's had a lot of practice with that motion.
# Agreed, that was hilarious.
#
# Jeremy Clarkson got a hold of one of these during Top Gear's race across Japan between a GTR and public transport (including a bullet train).  It looks like it's genuinely fun, even though it doesn't have the range of a real guitar.
# ROFLMAO!!!! SHAKING HIS HEAD! Jetdaisuke is the best person on youtube...no one episode is the same..
# i would get one of those!! my whole life im like "i wish i could have a guitar i could have around in my pocket!
# yo si prefiero mi hermosa guitarra real :D
# that looks like fun. I wouldn't mind having one of those for the fun of it.
# You're friggin awesome :D
# SO GOOD!!!
# HAHAHA! wow, this guy is crazy.
# love it.
# These Japan kids always have funky stuff!
# AMAZING
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))


word_tokens = word_tokenize(str(all))  
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]

filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        new_string = ''.join(char for char in w if char.isalnum())
        if new_string != '' and new_string != 'I' and 1 != len(new_string) :
            filtered_sentence.append(new_string)
        
print(filtered_sentence)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\AI\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from wordcloud import WordCloud # 클래스
wc = WordCloud(background_color="white", 
               font_path="C:\Windows\Fonts\malgunsl.ttf",
               random_state=802)
reviews = " ".join(filtered_sentence) # 하나의 문자열로 변경
cloud = wc.generate_from_text(reviews)
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
plt.imshow(cloud)
plt.axis("off") # x축,y축 끄기
plt.savefig("./보고서8.jpg") # 그림저장
plt.show()

# %% [markdown]
# # 단어가 있는것들중에 상위 15개 단어 시각화 하기

# %%
from collections import Counter
wordcount = Counter(filtered_sentence)
print(wordcount.most_common())
temp = wordcount.copy() #명사들만 호출한거 temp에 넣기
for i in temp:         # temp 안에 한개씩 호출
    if len(i) == 1:    # 길이가 한개인 단어일경우
        del wordcount[i]#제거함
import collections
import matplotlib.pyplot as plt
count = dict(Counter(wordcount).most_common(15)) #상위 15개 뽑기
print(count)
plt.figure(figsize=(15,15), dpi=80)
plt.bar(count.keys(), count.values())
plt.savefig("./보고서8plt.jpg")
plt.show()
# Out:
# [('nose', 27), ('guitar', 25), ('like', 25), ('one', 20), ('want', 18), ('nt', 16), ('real', 14), ('love', 13), ('thing', 13), ('cool', 12), ('play', 11), ('funny', 11), ('know', 10), ('would', 9), ('air', 9), ('pretty', 8), ('guy', 8), ('nice', 8), ('much', 8), ('think', 8), ('looks', 7), ('fun', 7), ('get', 7), ('buy', 7), ('said', 7), ('got', 6), ('im', 6), ('shit', 6), ('go', 6), ('haha', 6), ('actually', 6), ('dude', 6), ('nunoslbbcb11', 6), ('see', 5), ('even', 5), ('could', 5), ('awesome', 5), ('crazy', 5), ('The', 5), ('fucking', 5), ('make', 5), ('stop', 5), ('xD', 5), ('man', 5), ('123', 5), ('head', 5), ('tampon', 5), ('una', 5), ('Japan', 4), ('youtube', 4), ('hell', 4), ('Japanese', 4), ('face', 4), ('video', 4), ('thats', 4), ('English', 4), ('something', 4), ('japanese', 4), ('good', 4), ('dont', 4), ('understand', 4), ('wtf', 4), ('XD', 4), ('lol', 4), ('bleeding', 4), ('que', 4), ('bloody', 4), ('di', 4), ('le', 4), ('che', 4), ('great', 3), ('fast', 3), ('hilarious'
# ...

# %%
for i in range(120) :
    body = driver.find_element(By.TAG_NAME,"body")
    body.send_keys(Keys.END)
    time.sleep(0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
#       2 body = driver.find_element(By.TAG_NAME,"body")
#       3 body.send_keys(Keys.END)
# ----> 4 time.sleep(0.5)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
#       2 body = driver.find_element(By.TAG_NAME,"body")
#       3 body.send_keys(Keys.END)
# ----> 4 time.sleep(0.5)
#
# KeyboardInterrupt:
